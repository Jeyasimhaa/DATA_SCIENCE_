# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.prepocessing

# %%
df = pd.read_csv(r"C:\Users\rjey0\Downloads\practise\Social_Network_Ads.csv")
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = df[['Age', 'EstimatedSalary']]
y = df['Purchased']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model = KNeighborsClassifier(n_neighbors=5, metric='Value', p=2)

# %%
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 model.fit(X_train,y_train)
#
# File c:\Users\rjey0\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1329, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1324 partial_fit_and_fitted = (
#    1325     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1326 )
#    1328 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
#    1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\rjey0\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:492, in BaseEstimator._validate_params(self)
#     484 def _validate_params(self):
#     485     """Validate types and values of constructor parameters
#     486
#     487     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    490     accepted constraints.
#     491     """
# --> 492     validate_parameter_constraints(
#     493         self._parameter_constraints,
#     494         self.get_params(deep=False),
#     495         caller_name=self.__class__.__name__,
#     496     )
#
# File c:\Users\rjey0\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'metric' parameter of KNeighborsClassifier must be a str among {'pyfunc', 'l1', 'l2', 'minkowski', 'correlation', 'dice', 'infinity', 'nan_euclidean', 'canberra', 'p', 'russellrao', 'jaccard', 'cityblock', 'haversine', 'rogerstanimoto', 'cosine', 'mahalanobis', 'chebyshev', 'braycurtis', 'manhattan', 'sqeuclidean', 'sokalmichener', 'precomputed', 'hamming', 'euclidean', 'yule', 'seuclidean', 'sokalsneath'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'Value' instead.
